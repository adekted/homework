# %%
# Imports for selenium
import re
import requests
import math
import json
import pandas as pd
from pprint import pprint
from bs4 import BeautifulSoup as bs
from splinter import Browser

def init_browser():   
    # Chrome driver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
"""
This function is to parse out content using a regular expression pattern from a string.
<param>regex_pattern</param>
<param>string</param>
"""
def parse_definition(regex_pattern, string):
    result = re.compile(regex_pattern, flags=re.MULTILINE|re.DOTALL)
    # Checking if the patten works for the string
    if not result.search(string):
        return "None"
    else:
        return result.search(string).group(1)

# %%
def artist_code(artist):
    browser = init_browser()
    # URL for queries
    url = f'https://www.songkick.com/search?utf8=✓&type=initial&query={artist.replace(" ", "+")}'
    browser.visit(url)
    html = browser.html
    soup = bs(html, "html.parser")
    # Find the href for the URL with the page link
    container = soup.find("div", class_="sticky-container")
    row = container.find("div", class_="row")
    col = row.find("div", class_="col-8 primary")
    ul = col.find("ul")
    page_link = ul.find("a", class_="thumb")["href"]
    # Running the function
    artist_code = parse_definition('/artists/(\\d+)-', str(page_link))
    # Returns the artist code 
    return artist_code

# %%
# This will create a DB that will be thrown into a MongoDB to use
def concert_info(artist_code):
    # Initialzing Python dictionary
    concert_info = {}
    # Lists to store info to append to dictionary
    base_artist = []
    base_artist.append(artist_code)
    event_number = []
    event_name = []
    popularity = []
    location = []
    longitude = []
    latitude = []
    city = []
    start_date = []
    start_time = []
    for x in range(len(base_artist)):
        base_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist[x])+"/gigography.json?apikey=ORhDmrgUGkhdnXgP"+"&page=1"
        base_artist_2 = base_artist[x]
        total_entries = requests.get(base_url).json()['resultsPage']['totalEntries']
        pages = total_entries/50
        total_pages = math.ceil(pages)
        counter = 1
        
        for y in range(total_pages):
            artist_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist_2)+"/gigography.json?apikey="+"ORhDmrgUGkhdnXgP"+"&page="+(str(y+1))
            artist_json = requests.get(artist_url).json()
            for x in artist_json['resultsPage']['results']['event']:
                if str(x['location']['city']).split(",")[-1].strip() == "US" and str(x['venue']['lat']) != "None" and str(x['venue']['lng']) != "None":
                    event_number.append(counter)
                    event_name.append(str(x['displayName']))
                    popularity.append(str(x['popularity']))
                    location.append(str(x['venue']['displayName']))
                    longitude.append(str(x['venue']['lng']))
                    latitude.append(str(x['venue']['lat']))
                    city.append(str(x['location']['city']))
                    start_date.append(str(x['start']['date']))
                    start_time.append(str(x['start']['time']))
                    counter += 1
    artist_pd = pd.DataFrame({
        "Event Number": event_number,
        "Event Name": event_name,
        "Popularity": popularity,
        "Venue": location,
        "Longitude": longitude,
        "Latitude": latitude,
        "City": city,
        "Start Date": start_date,
        "Start Time": start_time
    })
    indexed_pd = artist_pd.set_index("Event Number")
    indexed_pd.to_csv(artist_code + "_events.csv")
    pd_json = json.loads(indexed_pd.reset_index().to_json(orient='records'))
    return pd_json

# %%
dream_events = concert_info(artist_code("Dream Theater"))
bruno_events = concert_info(artist_code("Bruno Mars"))
garth_events = concert_info(artist_code("Garth Brooks"))
eminem_events = concert_info(artist_code("Eminem"))
radiohead_events = concert_info(artist_code("Radiohead"))
beyonce_events = concert_info(artist_code("Beyonce"))
kanye_events = concert_info(artist_code("Kanye West"))
mana_events = concert_info(artist_code("Mana"))
odesza_events = concert_info(artist_code("Odesza"))
jcole_events = concert_info(artist_code("J Cole"))
mayer_events = concert_info(artist_code("John Mayer"))
russ_events = concert_info(artist_code("Russ"))
sza_events = concert_info(artist_code("SZA"))
trippie_events = concert_info(artist_code("Trippie Redd"))

# %%
trippie_events
# Out:
# [{'City': 'Mountain View, CA, US',
#   'Event Name': 'Rolling Loud Festival 2017',
#   'Event Number': 1,
#   'Latitude': '37.42332',
#   'Longitude': '-122.07803',
#   'Popularity': '0.649488',
#   'Start Date': '2017-10-21',
#   'Start Time': 'None',
#   'Venue': 'Shoreline Amphitheatre'},
#  {'City': 'San Bernardino, CA, US',
#   'Event Name': 'Rolling Loud Festival 2017',
#   'Event Number': 2,
#   'Latitude': '34.08973',
#   'Longitude': '-117.29406',
#   'Popularity': '0.326749',
#   'Start Date': '2017-12-16',
#   'Start Time': '13:00:00',
#   'Venue': 'NOS Events Center'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'Trippie Redd with Tiiiiiiiiiip at Music Hall (January 13, 2018)',
#   'Event Number': 3,
#   'Latitude': '44.9804803',
#   'Longitude': '-93.2744249',
#   'Popularity': '0.008772',
#   'Start Date': '2018-01-13',
#   'Start Time': '19:00:00',
#   'Venue': 'Music Hall'},
#  {'City': 'Santa Ana, CA, US',
#   'Event Name': 'Trippie Redd at The Observatory (January 14, 2018)',
#   'Event Number': 4,
#   'Latitude': '33.6998449',
#   'Longitude': '-117.9194457',
#   'Popularity': '0.008894',
#   'Start Date': '2018-01-14',
#   'Start Time': '20:00:00',
#   'Venue': 'The Observatory'},
#  {'City': 'Santa Ana, CA, US',
#   'Event Name': 'Trippie Redd at The Observatory (January 14, 2018)',
#   'Event Number': 5,
#   'Latitude': '33.6998449',
#   'Longitude': '-117.9194457',
#   'Popularity': '0.008894',
#   'Start Date': '2018-01-14',
#   'Start Time': '23:00:00',
#   'Venue': 'The Observatory'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Trippie Redd at The Novo by Microsoft (January 15, 2018)',
#   'Event Number': 6,
#   'Latitude': '34.0449376',
#   'Longitude': '-118.2654979',
#   'Popularity': '0.009018',
#   'Start Date': '2018-01-15',
#   'Start Time': '19:00:00',
#   'Venue': 'The Novo by Microsoft'},
#  {'City': 'Sugar Land, TX, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Smart Financial Centre (February 15, 2018)',
#   'Event Number': 7,
#   'Latitude': '29.5770582',
#   'Longitude': '-95.6432928',
#   'Popularity': '0.180737',
#   'Start Date': '2018-02-15',
#   'Start Time': '20:00:00',
#   'Venue': 'Smart Financial Centre'},
#  {'City': 'Irving, TX, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Pavilion at the Toyota Music Factory (February 17, 2018)',
#   'Event Number': 8,
#   'Latitude': '32.8750507',
#   'Longitude': '-96.9445262',
#   'Popularity': '0.191133',
#   'Start Date': '2018-02-17',
#   'Start Time': '19:00:00',
#   'Venue': 'Pavilion at the Toyota Music Factory'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Austin City Limits Live at The Moody Theater (February 18, 2018)',
#   'Event Number': 9,
#   'Latitude': '30.2653712',
#   'Longitude': '-97.7472955',
#   'Popularity': '0.181475',
#   'Start Date': '2018-02-18',
#   'Start Time': '19:00:00',
#   'Venue': 'Austin City Limits Live at The Moody Theater'},
#  {'City': 'Phoenix, AZ, US',
#   'Event Name': 'G-Eazy with Trippie Redd, Phora, and Anthony Russo at Comerica Theatre (February 20, 2018)',
#   'Event Number': 10,
#   'Latitude': '33.448775',
#   'Longitude': '-112.079564',
#   'Popularity': '0.182007',
#   'Start Date': '2018-02-20',
#   'Start Time': '19:30:00',
#   'Venue': 'Comerica Theatre'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at The Wiltern (February 22, 2018)',
#   'Event Number': 11,
#   'Latitude': '34.0619389',
#   'Longitude': '-118.3088392',
#   'Popularity': '0.182856',
#   'Start Date': '2018-02-22',
#   'Start Time': '18:00:00',
#   'Venue': 'The Wiltern'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at The Wiltern (February 23, 2018)',
#   'Event Number': 12,
#   'Latitude': '34.0619389',
#   'Longitude': '-118.3088392',
#   'Popularity': '0.183148',
#   'Start Date': '2018-02-23',
#   'Start Time': '18:00:00',
#   'Venue': 'The Wiltern'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'G-Eazy with Anthony Russo, Trippie Redd, and Phora at Shrine Expo Hall (February 24, 2018)',
#   'Event Number': 13,
#   'Latitude': '34.0242739',
#   'Longitude': '-118.2806695',
#   'Popularity': '0.183408',
#   'Start Date': '2018-02-24',
#   'Start Time': '18:30:00',
#   'Venue': 'Shrine Expo Hall'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Park Theater, Park MGM Las Vegas (February 25, 2018)',
#   'Event Number': 14,
#   'Latitude': '36.1050207',
#   'Longitude': '-115.1735947',
#   'Popularity': '0.202787',
#   'Start Date': '2018-02-25',
#   'Start Time': '19:00:00',
#   'Venue': 'Park Theater, Park MGM Las Vegas'},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Bill Graham Civic Auditorium (February 28, 2018)',
#   'Event Number': 15,
#   'Latitude': '37.7785099',
#   'Longitude': '-122.4174684',
#   'Popularity': '0.184443',
#   'Start Date': '2018-02-28',
#   'Start Time': '20:00:00',
#   'Venue': 'Bill Graham Civic Auditorium'},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Fox Theater (March 1, 2018)',
#   'Event Number': 16,
#   'Latitude': '37.8078474',
#   'Longitude': '-122.2699981',
#   'Popularity': '0.184693',
#   'Start Date': '2018-03-01',
#   'Start Time': '20:00:00',
#   'Venue': 'Fox Theater'},
#  {'City': 'Kent, WA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at ShoWare Center (March 3, 2018)',
#   'Event Number': 17,
#   'Latitude': '47.3867468',
#   'Longitude': '-122.241284',
#   'Popularity': '0.185181',
#   'Start Date': '2018-03-03',
#   'Start Time': '19:00:00',
#   'Venue': 'ShoWare Center'},
#  {'City': 'Broomfield, CO, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at 1stBANK Center (March 6, 2018)',
#   'Event Number': 18,
#   'Latitude': '39.904696',
#   'Longitude': '-105.085281',
#   'Popularity': '0.186089',
#   'Start Date': '2018-03-06',
#   'Start Time': '19:00:00',
#   'Venue': '1stBANK Center'},
#  {'City': 'St. Paul, MN, US',
#   'Event Name': 'G-Eazy with Trippie Redd, Phora, and Anthony Russo at Roy Wilkins Auditorium, St. Paul Rivercentre (March 8, 2018)',
#   'Event Number': 19,
#   'Latitude': '44.9434375',
#   'Longitude': '-93.1001445',
#   'Popularity': '0.186894',
#   'Start Date': '2018-03-08',
#   'Start Time': '19:00:00',
#   'Venue': 'Roy Wilkins Auditorium, St. Paul Rivercentre'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'Trippie Redd with Femdot at Portage Theater (March 9, 2018)',
#   'Event Number': 20,
#   'Latitude': '41.9543517',
#   'Longitude': '-87.749032',
#   'Popularity': '0.015713',
#   'Start Date': '2018-03-09',
#   'Start Time': '18:00:00',
#   'Venue': 'Portage Theater'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'G-Eazy with Phora, Anthony Russo, and Trippie Redd at Aragon Ballroom (March 9, 2018)',
#   'Event Number': 21,
#   'Latitude': '41.9692552',
#   'Longitude': '-87.6579453',
#   'Popularity': '0.187156',
#   'Start Date': '2018-03-09',
#   'Start Time': '19:00:00',
#   'Venue': 'Aragon Ballroom'},
#  {'City': 'Atlantic City, NJ, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Borgata Event Center (March 16, 2018)',
#   'Event Number': 22,
#   'Latitude': '39.3770706',
#   'Longitude': '-74.4345188',
#   'Popularity': '0.188941',
#   'Start Date': '2018-03-16',
#   'Start Time': '19:00:00',
#   'Venue': 'Borgata Event Center'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at DAR Constitution Hall (March 17, 2018)',
#   'Event Number': 23,
#   'Latitude': '38.8936076',
#   'Longitude': '-77.0397162',
#   'Popularity': '0.189143',
#   'Start Date': '2018-03-17',
#   'Start Time': '19:00:00',
#   'Venue': 'DAR Constitution Hall'},
#  {'City': 'Boston, MA, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Agganis Arena (March 18, 2018)',
#   'Event Number': 24,
#   'Latitude': '42.3517889',
#   'Longitude': '-71.117785',
#   'Popularity': '0.189345',
#   'Start Date': '2018-03-18',
#   'Start Time': '19:00:00',
#   'Venue': 'Agganis Arena'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'G-Eazy with Phora, Trippie Redd, and Anthony Russo at Radio City Music Hall (March 20, 2018)',
#   'Event Number': 25,
#   'Latitude': '40.760114',
#   'Longitude': '-73.980024',
#   'Popularity': '0.189847',
#   'Start Date': '2018-03-20',
#   'Start Time': '19:00:00',
#   'Venue': 'Radio City Music Hall'},
#  {'City': 'Raleigh, NC, US',
#   'Event Name': 'Trippie Redd, Whethan, Zeds Dead, MATOMA, and 3 more… at Red Hat Amphitheater (April 14, 2018)',
#   'Event Number': 26,
#   'Latitude': '35.7737725',
#   'Longitude': '-78.643066',
#   'Popularity': '0.062554',
#   'Start Date': '2018-04-14',
#   'Start Time': '16:00:00',
#   'Venue': 'Red Hat Amphitheater'},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'Berner, 2 Chainz, Chief Keef, Trippie Redd, and 1 more… at Bill Graham Civic Auditorium (April 20, 2018)',
#   'Event Number': 27,
#   'Latitude': '37.7785099',
#   'Longitude': '-122.4174684',
#   'Popularity': '0.261634',
#   'Start Date': '2018-04-20',
#   'Start Time': '17:30:00',
#   'Venue': 'Bill Graham Civic Auditorium'},
#  {'City': 'Long Beach, CA, US',
#   'Event Name': 'The Smokers Club 2018',
#   'Event Number': 28,
#   'Latitude': '33.75255',
#   'Longitude': '-118.19025',
#   'Popularity': '0.557128',
#   'Start Date': '2018-04-28',
#   'Start Time': 'None',
#   'Venue': 'Queen Mary Events Park'},
#  {'City': 'Charlotte, NC, US',
#   'Event Name': 'Trippie Redd and Migos at Charlotte Metro Credit Union Amphitheatre (May 1, 2018)',
#   'Event Number': 29,
#   'Latitude': '35.2393768',
#   'Longitude': '-80.8456537',
#   'Popularity': '0.180663',
#   'Start Date': '2018-05-01',
#   'Start Time': '19:30:00',
#   'Venue': 'Charlotte Metro Credit Union Amphitheatre'},
#  {'City': 'Southaven, MS, US',
#   'Event Name': 'Trippie Redd, Migos, Lil Baby, and Lil Yachty at Landers Center (May 3, 2018)',
#   'Event Number': 30,
#   'Latitude': '34.931985',
#   'Longitude': '-89.9969882',
#   'Popularity': '0.181248',
#   'Start Date': '2018-05-03',
#   'Start Time': '19:00:00',
#   'Venue': 'Landers Center'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'Playboi Carti, Bun B, Ski Mask The Slump God, Cozz, and 10 more… at Fair Park (May 4, 2018)',
#   'Event Number': 31,
#   'Latitude': '32.77586',
#   'Longitude': '-96.76416',
#   'Popularity': '0.39508',
#   'Start Date': '2018-05-04',
#   'Start Time': '14:00:00',
#   'Venue': 'Fair Park'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'Playboi Carti, Bun B, Ski Mask The Slump God, Cozz, and 9 more… at The Circuit of the Americas (cota) Lot A (May 5, 2018)',
#   'Event Number': 32,
#   'Latitude': '30.13416',
#   'Longitude': '-97.63843',
#   'Popularity': '0.39508',
#   'Start Date': '2018-05-05',
#   'Start Time': '14:00:00',
#   'Venue': 'The Circuit of the Americas (cota) Lot A'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'Playboi Carti, Bun B, Cozz, Kevin Gates, and 9 more… at Sam Houston Race Park (May 6, 2018)',
#   'Event Number': 33,
#   'Latitude': '29.93049',
#   'Longitude': '-95.54131',
#   'Popularity': '0.39508',
#   'Start Date': '2018-05-06',
#   'Start Time': '13:00:00',
#   'Venue': 'Sam Houston Race Park'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'Rolling Loud Festival 2018',
#   'Event Number': 34,
#   'Latitude': '25.68701',
#   'Longitude': '-80.35159',
#   'Popularity': '0.557128',
#   'Start Date': '2018-05-11',
#   'Start Time': '00:00:00',
#   'Venue': 'Hard Rock Stadium'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': "Trippie Redd, Migos, and PnB Rock at Festival Pier at Penn's Landing (May 19, 2018)",
#   'Event Number': 35,
#   'Latitude': '39.960258',
#   'Longitude': '-75.137185',
#   'Popularity': '0.192876',
#   'Start Date': '2018-05-19',
#   'Start Time': '19:00:00',
#   'Venue': "Festival Pier at Penn's Landing"},
#  {'City': 'Dover, DE, US',
#   'Event Name': 'Firefly Music Festival 2018',
#   'Event Number': 36,
#   'Latitude': '39.15817',
#   'Longitude': '-75.52437',
#   'Popularity': '0.895067',
#   'Start Date': '2018-06-14',
#   'Start Time': 'None',
#   'Venue': 'The Woodlands, Dover International Speedway'},
#  {'City': 'Des Moines, IA, US',
#   'Event Name': '515 Alive 2018',
#   'Event Number': 37,
#   'Latitude': '41.56896',
#   'Longitude': '-93.6474',
#   'Popularity': '0.329901',
#   'Start Date': '2018-08-17',
#   'Start Time': 'None',
#   'Venue': 'Water Works Park'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'Lyrical Lemonade Summer Smash 2018',
#   'Event Number': 38,
#   'Latitude': '41.86323',
#   'Longitude': '-87.70205',
#   'Popularity': '0.108282',
#   'Start Date': '2018-08-19',
#   'Start Time': '12:00:00',
#   'Venue': 'Douglas Park Cultural & Community Center'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'Trippie Redd with Spire at Spire Night Club (August 25, 2018)',
#   'Event Number': 39,
#   'Latitude': '29.75135',
#   'Longitude': '-95.36986',
#   'Popularity': '0.035302',
#   'Start Date': '2018-08-25',
#   'Start Time': '22:00:00',
#   'Venue': 'Spire Night Club'}]
