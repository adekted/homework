# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).load(function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader"></div>
#
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code: You may get confused')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %%
import pandas as pd
import numpy as np
import os

# Creating a path to the generated data
schools_file = os.path.join("Generators","PyCitySchools","generated_data","schools_complete.csv")
students_file = os.path.join("Generators","PyCitySchools","generated_data","students_complete.csv")

# Reading the two csv files
schools_pd = pd.read_csv(schools_file)
students_pd = pd.read_csv(students_file)

# Calculating total amount of students passed
passed_reading = students_pd.loc[students_pd["reading_score"] >= 70, :]
passed_math = students_pd.loc[students_pd["math_score"] >= 70, :]

# Calculating totals and averages of schools and students
total_schools = len(schools_pd['school_name'].unique())
total_students = len(students_pd['Student ID'].unique())
total_budget = '${:,.2f}'.format(schools_pd['budget'].sum())
average_reading = round(students_pd['reading_score'].mean(), 2)
average_math = round(students_pd['math_score'].mean(),2)

# Calculating the passing rates for reading, math and overall
rate_reading = round(len(passed_reading)/len(students_pd['Student ID'].unique())*100,2)
rate_math = round(len(passed_math)/len(students_pd['Student ID'].unique())*100,2)
rate_overall = round(((rate_reading+rate_math)/2),2)

summary_table = pd.DataFrame({
    "Total Schools": [total_schools],
    "Total Students": [total_students],
    "Total Budget": [total_budget],
    "Average Math Score": [average_math],
    "Average Reading Score": [average_reading],
    "% Passing Math": [rate_math],
    "% Passing Reading": [rate_reading],
    "% Passing Overall": [rate_overall]
                             })
summary_table_organized = summary_table[['Total Schools', 'Total Students','Total Budget','Average Math Score','Average Reading Score',\
                            '% Passing Math','% Passing Reading','% Passing Overall']]
summary_table_organized
# Out:
#    Total Schools  Total Students    Total Budget  Average Math Score  \
# 0             11           29376  $18,648,468.00               82.27
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Passing Overall
# 0                  82.87           86.86              78.22              82.54

# %%
students_df.loc[students_df['grade'] == '9th'].groupby('school')["math_score"].mean()
# Out:
#        School ID            school_name      type  size   budget  Student ID  \
# 0              0     Miller High School   Charter  2424  1418040           0
# 1              0     Miller High School   Charter  2424  1418040           1
# 2              0     Miller High School   Charter  2424  1418040           2
# 3              0     Miller High School   Charter  2424  1418040           3
# 4              0     Miller High School   Charter  2424  1418040           4
# 2424           1    Sherman High School  District  3213  2152710        2424
# 2425           1    Sherman High School  District  3213  2152710        2425
# 2426           1    Sherman High School  District  3213  2152710        2426
# 2427           1    Sherman High School  District  3213  2152710        2427
# 2428           1    Sherman High School  District  3213  2152710        2428
# 5637           2   Galloway High School   Charter  2471  1445535        5637
# 5638           2   Galloway High School   Charter  2471  1445535        5638
# 5639           2   Galloway High School   Charter  2471  1445535        5639
# 5640           2   Galloway High School   Charter  2471  1445535        5640
# 5641           2   Galloway High School   Charter  2471  1445535        5641
# 8108           3      Smith High School  District  4954  3210192        8108
# 8109           3      Smith High School  District  4954  3210192        8109
# 8110           3      Smith High School  District  4954  3210192        8110
# 8111           3      Smith High School  District  4954  3210192        8111
# 8112           3      Smith High School  District  4954  3210192        8112
# 13062          4      Kelly High School  District  3307  2225611       13062
# 13063          4      Kelly High School  District  3307  2225611       13063
# 13064          4      Kelly High School  District  3307  2225611       13064
# 13065          4      Kelly High School  District  3307  2225611       13065
# 13066          4      Kelly High School  District  3307  2225611       13066
# 16369          5    Hawkins High School  District  4555  2851430       16369
# 16370          5    Hawkins High School  District  4555  2851430       16370
# 16371          5    Hawkins High School  District  4555  2851430       16371
# 16372          5    Hawkins High School  District  4555  2851430       16372
# 16373          5    Hawkins High School  District  4555  2851430       16373
# 20924          6   Gonzalez High School   Charter  1855  1192765       20924
# 20925          6   Gonzalez High School   Charter  1855  1192765       20925
# 20926          6   Gonzalez High School   Charter  1855  1192765       20926
# 20927          6   Gonzalez High School   Charter  1855  1192765       20927
