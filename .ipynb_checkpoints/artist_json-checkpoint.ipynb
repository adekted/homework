# %%
# Imports for selenium
import re
import requests
import math
import json
import pandas as pd
from pprint import pprint
from bs4 import BeautifulSoup as bs
from splinter import Browser

def init_browser():   
    # Chrome driver
    executable_path = {"executable_path": "chromedriver"}
    return Browser("chrome", **executable_path, headless=False)

# %%
"""
This function is to parse out content using a regular expression pattern from a string.
<param>regex_pattern</param>
<param>string</param>
"""
def parse_definition(regex_pattern, string):
    result = re.compile(regex_pattern, flags=re.MULTILINE|re.DOTALL)
    # Checking if the patten works for the string
    if not result.search(string):
        return "None"
    else:
        return result.search(string).group(1)

# %%
def artist_code(artist):
    browser = init_browser()
    # URL for queries
    url = f'https://www.songkick.com/search?utf8=✓&type=initial&query={artist.replace(" ", "+")}'
    browser.visit(url)
    html = browser.html
    soup = bs(html, "html.parser")
    # Find the href for the URL with the page link
    container = soup.find("div", class_="sticky-container")
    row = container.find("div", class_="row")
    col = row.find("div", class_="col-8 primary")
    ul = col.find("ul")
    page_link = ul.find("a", class_="thumb")["href"]
    # Running the function
    artist_code = parse_definition('/artists/(\\d+)-', str(page_link))
    # Returns the artist code 
    return artist_code

# %%
# This will create a DB that will be thrown into a MongoDB to use
def concert_info(artist_code):
    # Initialzing Python dictionary
    concert_info = {}
    # Lists to store info to append to dictionary
    base_artist = []
    base_artist.append(artist_code)
    event_number = []
    event_name = []
    popularity = []
    location = []
    longitude = []
    latitude = []
    city = []
    start_date = []
    start_time = []
    for x in range(len(base_artist)):
        base_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist[x])+"/gigography.json?apikey=ORhDmrgUGkhdnXgP"+"&page=1"
        base_artist_2 = base_artist[x]
        total_entries = requests.get(base_url).json()['resultsPage']['totalEntries']
        pages = total_entries/50
        total_pages = math.ceil(pages)
        print('PRINTING EVENTS FOR ARTIST: ' + str(base_artist[x]))
        counter = 1
        
        for y in range(total_pages):
            artist_url = "https://api.songkick.com/api/3.0/artists/"+str(base_artist_2)+"/gigography.json?apikey="+"ORhDmrgUGkhdnXgP"+"&page="+(str(y+1))
            artist_json = requests.get(artist_url).json()
            for x in artist_json['resultsPage']['results']['event']:
                if str(x['location']['city']).split(",")[-1].strip() == "US":
                    event_number.append(counter)
                    event_name.append(str(x['displayName']))
                    popularity.append(str(x['popularity']))
                    location.append(str(x['venue']['displayName']))
                    longitude.append(str(x['venue']['lat']))
                    latitude.append(str(x['venue']['lng']))
                    city.append(str(x['location']['city']))
                    start_date.append(str(x['start']['date']))
                    start_time.append(str(x['start']['time']))
                    counter += 1
    artist_pd = pd.DataFrame({
        "Event Number": event_number,
        "Event Name": event_name,
        "Popularity": popularity,
        "Venue": location,
        "Longitude": longitude,
        "Latitude": latitude,
        "City": city,
        "Start Date": start_date,
        "Start Time": start_time
    })
    indexed_pd = artist_pd.set_index("Event Number")
    pd_json = json.loads(indexed_pd.reset_index().to_json(orient='records'))
    return pd_json

# %%
concert_info(artist_code("RL Grime"))
# Out:
# PRINTING EVENTS FOR ARTIST: 4586543
# [{'City': 'New York, NY, US',
#   'Event Name': 'Shlohmo with RL Grime and SK Shlomo at The Studio at Webster Hall (September 17, 2011)',
#   'Event Number': 1,
#   'Latitude': '-73.9892',
#   'Longitude': '40.73155',
#   'Popularity': '0.039798',
#   'Start Date': '2011-09-17',
#   'Start Time': '19:00:00',
#   'Venue': 'The Studio at Webster Hall'},
#  {'City': 'Baltimore, MD, US',
#   'Event Name': 'Mimosa with The M Machine, RL Grime, and Helixx at Baltimore Soundstage (November 8, 2011)',
#   'Event Number': 2,
#   'Latitude': '-76.6068397',
#   'Longitude': '39.2876066',
#   'Popularity': '0.038505',
#   'Start Date': '2011-11-08',
#   'Start Time': '20:00:00',
#   'Venue': 'Baltimore Soundstage'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'Mimosa with The M Machine and RL Grime at Theater of the Living Arts (November 9, 2011)',
#   'Event Number': 3,
#   'Latitude': '-75.148678',
#   'Longitude': '39.941305',
#   'Popularity': '0.038505',
#   'Start Date': '2011-11-09',
#   'Start Time': '20:00:00',
#   'Venue': 'Theater of the Living Arts'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Shlohmo with Jonwayne, Groundislava, RL Grime, and 2 more… at Echoplex (December 29, 2011)',
#   'Event Number': 4,
#   'Latitude': '-118.2606087',
#   'Longitude': '34.0775855',
#   'Popularity': '0.038505',
#   'Start Date': '2011-12-29',
#   'Start Time': '20:00:00',
#   'Venue': 'Echoplex'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Shlohmo with LOL Boys and RL Grime at The Studio at Webster Hall (May 3, 2012)',
#   'Event Number': 5,
#   'Latitude': '-73.9891987',
#   'Longitude': '40.7315472',
#   'Popularity': '0.038505',
#   'Start Date': '2012-05-03',
#   'Start Time': '19:30:00',
#   'Venue': 'The Studio at Webster Hall'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'T.E.E.D with RL Grime and Anna Lunoe at Echoplex (August 9, 2012)',
#   'Event Number': 6,
#   'Latitude': '-118.2606087',
#   'Longitude': '34.0775855',
#   'Popularity': '0.038517',
#   'Start Date': '2012-08-09',
#   'Start Time': '20:30:00',
#   'Venue': 'Echoplex'},
#  {'City': 'Denver, CO, US',
#   'Event Name': "RL Grime at Cervantes' Masterpiece Ballroom (August 11, 2012)",
#   'Event Number': 7,
#   'Latitude': '-104.9785364',
#   'Longitude': '39.7544946',
#   'Popularity': '0.038505',
#   'Start Date': '2012-08-11',
#   'Start Time': '20:00:00',
#   'Venue': "Cervantes' Masterpiece Ballroom"},
#  {'City': 'Chula Vista, CA, US',
#   'Event Name': 'Identity Festival LED Stage 2012',
#   'Event Number': 8,
#   'Latitude': '-117.0060564',
#   'Longitude': '32.5882959',
#   'Popularity': '0.038505',
#   'Start Date': '2012-08-18',
#   'Start Time': '12:00:00',
#   'Venue': 'Mattress Firm Amphitheatre'},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'RL Grime at 103 Harriet (September 7, 2012)',
#   'Event Number': 9,
#   'Latitude': '-122.4059826',
#   'Longitude': '37.7781545',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-07',
#   'Start Time': '22:00:00',
#   'Venue': '103 Harriet'},
#  {'City': 'Seattle, WA, US',
#   'Event Name': 'Lunice and RL Grime at Neumos Crystal Ball Reading Room (September 12, 2012)',
#   'Event Number': 10,
#   'Latitude': '-122.3200355',
#   'Longitude': '47.6140125',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-12',
#   'Start Time': '21:00:00',
#   'Venue': 'Neumos Crystal Ball Reading Room'},
#  {'City': 'Burlington, VT, US',
#   'Event Name': 'RL Grime at Club Metronome (September 20, 2012)',
#   'Event Number': 11,
#   'Latitude': '-73.2117',
#   'Longitude': '44.47606',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-20',
#   'Start Time': '21:00:00',
#   'Venue': 'Club Metronome'},
#  {'City': 'Richmond, VA, US',
#   'Event Name': 'RL Grime at Kingdom (September 21, 2012)',
#   'Event Number': 12,
#   'Latitude': '-77.427508',
#   'Longitude': '37.533651',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-21',
#   'Start Time': '20:30:00',
#   'Venue': 'Kingdom'},
#  {'City': 'Hollywood, CA, US',
#   'Event Name': "RL Grime at Drai's Hollywood (September 23, 2012)",
#   'Event Number': 13,
#   'Latitude': '-118.3259571',
#   'Longitude': '34.1013502',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-23',
#   'Start Time': 'None',
#   'Venue': "Drai's Hollywood"},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'Alesso, ATB, Avicii, Borgore, and 20 more… at Oracle Arena (September 29, 2012)',
#   'Event Number': 14,
#   'Latitude': '-122.20157',
#   'Longitude': '37.75155',
#   'Popularity': '0.4543',
#   'Start Date': '2012-09-29',
#   'Start Time': '18:00:00',
#   'Venue': 'Oracle Arena'},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'RL Grime at Oakland Alameda County Coliseum Complex (September 29, 2012)',
#   'Event Number': 15,
#   'Latitude': '-122.2028616',
#   'Longitude': '37.750277',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-29',
#   'Start Time': '18:00:00',
#   'Venue': 'Oakland Alameda County Coliseum Complex'},
#  {'City': 'Oakland, CA, US',
#   'Event Name': 'Beyond Wonderland Festival 2012',
#   'Event Number': 16,
#   'Latitude': '-122.2028616',
#   'Longitude': '37.750277',
#   'Popularity': '0.038505',
#   'Start Date': '2012-09-29',
#   'Start Time': 'None',
#   'Venue': 'Oakland Alameda County Coliseum Complex'},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'RL Grime at House Party (October 11, 2012)',
#   'Event Number': 17,
#   'Latitude': '-90.307322',
#   'Longitude': '38.653928',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-11',
#   'Start Time': 'None',
#   'Venue': 'House Party'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'RL Grime at MJQ Concourse (October 13, 2012)',
#   'Event Number': 18,
#   'Latitude': '-84.3631268',
#   'Longitude': '33.77396',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-13',
#   'Start Time': '23:00:00',
#   'Venue': 'MJQ Concourse'},
#  {'City': 'Lansing, MI, US',
#   'Event Name': 'RL Grime at Lansing Center (October 19, 2012)',
#   'Event Number': 19,
#   'Latitude': '-84.5482374',
#   'Longitude': '42.7335652',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-19',
#   'Start Time': '19:30:00',
#   'Venue': 'Lansing Center'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Monster Massive 2012',
#   'Event Number': 20,
#   'Latitude': '-118.2603254',
#   'Longitude': '34.0549094',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-27',
#   'Start Time': '17:00:00',
#   'Venue': 'Los Angeles Center Studios'},
#  {'City': 'San Diego, CA, US',
#   'Event Name': 'Afrojack and RL Grime at Petco Park (October 27, 2012)',
#   'Event Number': 21,
#   'Latitude': '-117.1556175',
#   'Longitude': '32.7056639',
#   'Popularity': '0.167131',
#   'Start Date': '2012-10-27',
#   'Start Time': '18:00:00',
#   'Venue': 'Petco Park'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'RL Grime at Los Angeles Center Studios (October 27, 2012)',
#   'Event Number': 22,
#   'Latitude': '-118.2603254',
#   'Longitude': '34.0549094',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-27',
#   'Start Time': '16:00:00',
#   'Venue': 'Los Angeles Center Studios'},
#  {'City': 'University Park, PA, US',
#   'Event Name': 'GLOWfest Presents Dancing in the Dark 2012',
#   'Event Number': 23,
#   'Latitude': '-77.8666435',
#   'Longitude': '40.8035111',
#   'Popularity': '0.107727',
#   'Start Date': '2012-10-30',
#   'Start Time': 'None',
#   'Venue': 'Bryce Jordan Center'},
#  {'City': 'Fort Lauderdale, FL, US',
#   'Event Name': 'Felix Cartal and RL Grime with Felix Cartel at Revolution (October 31, 2012)',
#   'Event Number': 24,
#   'Latitude': '-80.146162',
#   'Longitude': '26.121094',
#   'Popularity': '0.038648',
#   'Start Date': '2012-10-31',
#   'Start Time': '21:00:00',
#   'Venue': 'Revolution'},
#  {'City': 'Miami Beach, FL, US',
#   'Event Name': 'RL Grime at Cameo (October 31, 2012)',
#   'Event Number': 25,
#   'Latitude': '-80.1313994',
#   'Longitude': '25.7871243',
#   'Popularity': '0.038505',
#   'Start Date': '2012-10-31',
#   'Start Time': '23:00:00',
#   'Venue': 'Cameo'},
#  {'City': 'Madison, WI, US',
#   'Event Name': 'RL Grime at Liquid (December 8, 2012)',
#   'Event Number': 26,
#   'Latitude': '-89.3968713',
#   'Longitude': '43.0733915',
#   'Popularity': '0.038505',
#   'Start Date': '2012-12-08',
#   'Start Time': '21:00:00',
#   'Venue': 'Liquid'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Shlohmo with RL Grime, Groundislava, Ryan Hemsworth, and 2 more… at Echoplex (December 20, 2012)',
#   'Event Number': 27,
#   'Latitude': '-118.2606087',
#   'Longitude': '34.0775855',
#   'Popularity': '0.038505',
#   'Start Date': '2012-12-20',
#   'Start Time': '19:30:00',
#   'Venue': 'Echoplex'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'A-Trak and RL Grime with Toy Selectah, Nedu Lopes, and 1 more… at Stereo Live (December 21, 2012)',
#   'Event Number': 28,
#   'Latitude': '-95.4986635',
#   'Longitude': '29.7317677',
#   'Popularity': '0.059252',
#   'Start Date': '2012-12-21',
#   'Start Time': '20:00:00',
#   'Venue': 'Stereo Live'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'RL Grime with Nathaniel Knows and KELLAN at The Whiskey Bar (December 27, 2012)',
#   'Event Number': 29,
#   'Latitude': '-122.6713265',
#   'Longitude': '45.5227428',
#   'Popularity': '0.038505',
#   'Start Date': '2012-12-27',
#   'Start Time': '22:00:00',
#   'Venue': 'The Whiskey Bar'},
#  {'City': 'South Lake Tahoe, NV, US',
#   'Event Name': 'Baauer with RL Grime, Benjah Ninjah, and S1nth3sys at Blu Nightclub (December 29, 2012)',
#   'Event Number': 30,
#   'Latitude': '-119.9389565',
#   'Longitude': '38.9637449',
#   'Popularity': '0.06669',
#   'Start Date': '2012-12-29',
#   'Start Time': '22:30:00',
#   'Venue': 'Blu Nightclub'},
#  {'City': 'Stateline, NV, US',
#   'Event Name': 'Baauer with RL Grime and Minnesota at Blu Nightclub (December 29, 2012)',
#   'Event Number': 31,
#   'Latitude': '-119.9390422',
#   'Longitude': '38.9612432',
#   'Popularity': '0.06669',
#   'Start Date': '2012-12-29',
#   'Start Time': '23:00:00',
#   'Venue': 'Blu Nightclub'},
#  {'City': 'Santa Ana, CA, US',
#   'Event Name': 'Kendrick Lamar with RL Grime at The Observatory (December 31, 2012)',
#   'Event Number': 32,
#   'Latitude': '-117.9194457',
#   'Longitude': '33.6998449',
#   'Popularity': '0.517334',
#   'Start Date': '2012-12-31',
#   'Start Time': '20:00:00',
#   'Venue': 'The Observatory'},
#  {'City': 'Hollywood, CA, US',
#   'Event Name': 'Brenmar with RL Grime and Salva at Sunset Sound Studios (January 9, 2013)',
#   'Event Number': 33,
#   'Latitude': '-118.3361123',
#   'Longitude': '34.1010843',
#   'Popularity': '0.038505',
#   'Start Date': '2013-01-09',
#   'Start Time': '21:00:00',
#   'Venue': 'Sunset Sound Studios'},
#  {'City': 'Milwaukee, WI, US',
#   'Event Name': 'RL Grime with Run DMT, The Regulators, and DJ NO_ID at Miramar Theatre (January 17, 2013)',
#   'Event Number': 34,
#   'Latitude': '-87.8877808',
#   'Longitude': '43.0704976',
#   'Popularity': '0.038505',
#   'Start Date': '2013-01-17',
#   'Start Time': '21:00:00',
#   'Venue': 'Miramar Theatre'},
#  {'City': 'Columbus, OH, US',
#   'Event Name': "RL Grime at Skully's Music Diner (January 19, 2013)",
#   'Event Number': 35,
#   'Latitude': '-83.0054203',
#   'Longitude': '39.9858767',
#   'Popularity': '0.038505',
#   'Start Date': '2013-01-19',
#   'Start Time': '21:00:00',
#   'Venue': "Skully's Music Diner"},
#  {'City': 'Austin, TX, US',
#   'Event Name': "The Presets, Antwon, Brooke Candy, Pictureplane, and 28 more… at Emo's Austin (March 14, 2013)",
#   'Event Number': 36,
#   'Latitude': '-97.7282',
#   'Longitude': '30.2404',
#   'Popularity': '0.342653',
#   'Start Date': '2013-03-14',
#   'Start Time': '12:00:00',
#   'Venue': "Emo's Austin"},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'MØ, Major Lazer, Flosstradamus, Andrew W.K., and 17 more… at Beauty Ballroom (March 14, 2013)',
#   'Event Number': 37,
#   'Latitude': '-97.7282',
#   'Longitude': '30.2404',
#   'Popularity': '0.342653',
#   'Start Date': '2013-03-14',
#   'Start Time': '12:00:00',
#   'Venue': 'Beauty Ballroom'},
#  {'City': 'Austin, TX, US',
#   'Event Name': "Mexicans with Guns, Groundislava, Jerome Lol, Shlohmo, and 3 more… at Emo's Austin (March 15, 2013)",
#   'Event Number': 38,
#   'Latitude': '-97.7282016',
#   'Longitude': '30.2403964',
#   'Popularity': '0.131001',
#   'Start Date': '2013-03-15',
#   'Start Time': '21:00:00',
#   'Venue': "Emo's Austin"},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'Borgore, RL Grime, UZ, Birdy Nam Nam, and 4 more… at Hard Miami (March 20, 2013)',
#   'Event Number': 39,
#   'Latitude': '-80.193645',
#   'Longitude': '25.7806634',
#   'Popularity': '0.198859',
#   'Start Date': '2013-03-20',
#   'Start Time': '22:00:00',
#   'Venue': 'Hard Miami'},
#  {'City': 'Honolulu, HI, US',
#   'Event Name': "Clockwork and RL Grime at Kaka'ako Waterfront Park (March 30, 2013)",
#   'Event Number': 40,
#   'Latitude': '-157.8624995',
#   'Longitude': '21.2979701',
#   'Popularity': '0.038505',
#   'Start Date': '2013-03-30',
#   'Start Time': '18:00:00',
#   'Venue': "Kaka'ako Waterfront Park"},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'RL Grime with DJ Dials and Joaquin Bartra at The Independent (May 2, 2013)',
#   'Event Number': 41,
#   'Latitude': '-122.4378099',
#   'Longitude': '37.7755211',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-02',
#   'Start Time': '21:00:00',
#   'Venue': 'The Independent'},
#  {'City': 'Reno, NV, US',
#   'Event Name': 'RL Grime with Bass Science, Subtropixx, Maizon Tech, and 1 more… at 1up (May 3, 2013)',
#   'Event Number': 42,
#   'Latitude': '-119.8103787',
#   'Longitude': '39.5287037',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-03',
#   'Start Time': 'None',
#   'Venue': '1up'},
#  {'City': 'Seattle, WA, US',
#   'Event Name': 'RL Grime and Tony Goods at Chop Suey (May 4, 2013)',
#   'Event Number': 43,
#   'Latitude': '-122.3144509',
#   'Longitude': '47.613646',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-04',
#   'Start Time': 'None',
#   'Venue': 'Chop Suey'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'RL Grime with Obeyah at U Street Music Hall (May 7, 2013)',
#   'Event Number': 44,
#   'Latitude': '-77.027764',
#   'Longitude': '38.917202',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-07',
#   'Start Time': '21:00:00',
#   'Venue': 'U Street Music Hall'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'RL Grime with Speakerfoxxx and Taste Tester at The Basement (May 8, 2013)',
#   'Event Number': 45,
#   'Latitude': '-84.3467044',
#   'Longitude': '33.7400683',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-08',
#   'Start Time': '20:00:00',
#   'Venue': 'The Basement'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'RL Grime at Le Poisson Rouge (May 9, 2013)',
#   'Event Number': 46,
#   'Latitude': '-74.0000425',
#   'Longitude': '40.7285022',
#   'Popularity': '0.038505',
#   'Start Date': '2013-05-09',
#   'Start Time': '22:00:00',
#   'Venue': 'Le Poisson Rouge'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'Jambalaya Festival 2013',
#   'Event Number': 47,
#   'Latitude': '-95.3671824',
#   'Longitude': '29.7624411',
#   'Popularity': '0.189847',
#   'Start Date': '2013-05-23',
#   'Start Time': 'None',
#   'Venue': 'Revention Music Center'},
#  {'City': 'Bee Cave, TX, US',
#   'Event Name': 'Jambalaya Festival 2013',
#   'Event Number': 48,
#   'Latitude': '-97.954133',
#   'Longitude': '30.312563',
#   'Popularity': '0.189847',
#   'Start Date': '2013-05-24',
#   'Start Time': 'None',
#   'Venue': 'The Backyard'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'Tyler, The Creator, Earl Sweatshirt, Zeds Dead, Big Boi, and 1 more… at Austin Music Hall (May 24, 2013)',
#   'Event Number': 49,
#   'Latitude': '-97.749672',
#   'Longitude': '30.266745',
#   'Popularity': '0.178169',
#   'Start Date': '2013-05-24',
#   'Start Time': '16:00:00',
#   'Venue': 'Austin Music Hall'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'Big Boi and Zeds Dead with Tyler, The Creator, Earl Sweatshirt, and 2 more… at Palladium Ballroom (May 25, 2013)',
#   'Event Number': 50,
#   'Latitude': '-96.797987',
#   'Longitude': '32.768777',
#   'Popularity': '0.178169',
#   'Start Date': '2013-05-25',
#   'Start Time': '17:00:00',
#   'Venue': 'Palladium Ballroom'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'Jambalaya Festival 2013',
#   'Event Number': 51,
#   'Latitude': '-96.797987',
#   'Longitude': '32.768777',
#   'Popularity': '0.189847',
#   'Start Date': '2013-05-25',
#   'Start Time': 'None',
#   'Venue': 'Palladium Ballroom'},
#  {'City': 'Ozark, AR, US',
#   'Event Name': 'Wakarusa Festival 2013',
#   'Event Number': 52,
#   'Latitude': '-93.79719',
#   'Longitude': '35.71178',
#   'Popularity': '0.39175',
#   'Start Date': '2013-05-30',
#   'Start Time': '11:00:00',
#   'Venue': 'Mulberry Mountain Lodging and Events'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'Baauer and RL Grime at Skyway Theatre (June 26, 2013)',
#   'Event Number': 53,
#   'Latitude': '-93.274927',
#   'Longitude': '44.977412',
#   'Popularity': '0.06669',
#   'Start Date': '2013-06-26',
#   'Start Time': 'None',
#   'Venue': 'Skyway Theatre'},
#  {'City': 'Rothbury, MI, US',
#   'Event Name': 'Electric Forest Festival 2013',
#   'Event Number': 54,
#   'Latitude': '-86.3664',
#   'Longitude': '43.53865',
#   'Popularity': '0.265185',
#   'Start Date': '2013-06-28',
#   'Start Time': '10:00:00',
#   'Venue': 'Double JJ Ranch & Golf Resort'},
#  {'City': 'South Burlington, VT, US',
#   'Event Name': 'Baauer and RL Grime with Jim-e Stack at Higher Ground (July 9, 2013)',
#   'Event Number': 55,
#   'Latitude': '-73.17564',
#   'Longitude': '44.468887',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-09',
#   'Start Time': '21:00:00',
#   'Venue': 'Higher Ground'},
#  {'City': 'Mariaville, NY, US',
#   'Event Name': 'Camp Bisco 2013',
#   'Event Number': 56,
#   'Latitude': '-74.152758',
#   'Longitude': '42.823657',
#   'Popularity': '0.379584',
#   'Start Date': '2013-07-11',
#   'Start Time': '08:00:00',
#   'Venue': 'Indian Lookout Country Club'},
#  {'City': 'Columbus, OH, US',
#   'Event Name': "Baauer and RL Grime with Ryan Hemsworth and Jim-e Stack at Skully's Music Diner (July 15, 2013)",
#   'Event Number': 57,
#   'Latitude': '-83.0054203',
#   'Longitude': '39.9858767',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-15',
#   'Start Time': '20:00:00',
#   'Venue': "Skully's Music Diner"},
#  {'City': 'Millvale, PA, US',
#   'Event Name': "Baauer with RL Grime, Ryan Hemsworth, Jim-e Stack, and 2 more… at Mr. Small's Theatre (July 16, 2013)",
#   'Event Number': 58,
#   'Latitude': '-79.97268',
#   'Longitude': '40.481268',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-16',
#   'Start Time': '20:00:00',
#   'Venue': "Mr. Small's Theatre"},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'Baauer and RL Grime with Ryan Hemsworth and Jim-e Stack at Old Rock House (July 16, 2013)',
#   'Event Number': 59,
#   'Latitude': '-90.196469',
#   'Longitude': '38.615345',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-16',
#   'Start Time': '19:00:00',
#   'Venue': 'Old Rock House'},
#  {'City': 'Cincinnati, OH, US',
#   'Event Name': 'Baauer and RL Grime with Ryan Hemsworth and Jim-e Stack at Play (July 17, 2013)',
#   'Event Number': 60,
#   'Latitude': '-84.5123677',
#   'Longitude': '39.1038074',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-17',
#   'Start Time': '21:00:00',
#   'Venue': 'Play'},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'Baauer and RL Grime with Ryan Hemsworth and Jim-e Stack at Old Rock House (July 18, 2013)',
#   'Event Number': 61,
#   'Latitude': '-90.196469',
#   'Longitude': '38.615345',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-18',
#   'Start Time': '19:00:00',
#   'Venue': 'Old Rock House'},
#  {'City': 'Morrison, CO, US',
#   'Event Name': 'Global Dance Festival Red Rocks 2013',
#   'Event Number': 62,
#   'Latitude': '-105.19724',
#   'Longitude': '39.68001',
#   'Popularity': '0.065982',
#   'Start Date': '2013-07-19',
#   'Start Time': 'None',
#   'Venue': 'Red Rocks Amphitheatre'},
#  {'City': 'Lawrence, KS, US',
#   'Event Name': 'RL Grime with Baauer at Granada Theatre (July 19, 2013)',
#   'Event Number': 63,
#   'Latitude': '-95.2358532',
#   'Longitude': '38.9647957',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-19',
#   'Start Time': '21:00:00',
#   'Venue': 'Granada Theatre'},
#  {'City': 'Morrison, CO, US',
#   'Event Name': 'Global Dance Festival 2013',
#   'Event Number': 64,
#   'Latitude': '-105.19724',
#   'Longitude': '39.68001',
#   'Popularity': '0.049841',
#   'Start Date': '2013-07-19',
#   'Start Time': 'None',
#   'Venue': 'Red Rocks Amphitheatre'},
#  {'City': 'Omaha, NE, US',
#   'Event Name': 'Baauer with RL Grime, Jim-e Stack, and Buzz Junior at Slowdown (July 20, 2013)',
#   'Event Number': 65,
#   'Latitude': '-95.93399',
#   'Longitude': '41.266517',
#   'Popularity': '0.06669',
#   'Start Date': '2013-07-20',
#   'Start Time': 'None',
#   'Venue': 'Slowdown'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'HARD Summer Music Festival 2013',
#   'Event Number': 66,
#   'Latitude': '-118.2342745',
#   'Longitude': '34.0661704',
#   'Popularity': '0.271834',
#   'Start Date': '2013-08-03',
#   'Start Time': '12:00:00',
#   'Venue': 'Los Angeles State Historic Park'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'Major Lazer and Dillon Francis with Flosstradamus, Riff Raff, and 1 more… at The Masquerade - The Music Park (August 9, 2013)',
#   'Event Number': 67,
#   'Latitude': '-84.3648011',
#   'Longitude': '33.7710375',
#   'Popularity': '0.319561',
#   'Start Date': '2013-08-09',
#   'Start Time': 'None',
#   'Venue': 'The Masquerade - The Music Park'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Electric Zoo Festival 2013',
#   'Event Number': 68,
#   'Latitude': '-73.92567',
#   'Longitude': '40.78377',
#   'Popularity': '0.599349',
#   'Start Date': '2013-08-30',
#   'Start Time': '23:59:20',
#   'Venue': "Randall's Island"},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'North Coast Music Festival 2013',
#   'Event Number': 69,
#   'Latitude': '-87.66609',
#   'Longitude': '41.88512',
#   'Popularity': '0.265499',
#   'Start Date': '2013-08-30',
#   'Start Time': '12:00:00',
#   'Venue': 'Union Park'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'Diplo with RL Grime at Wonder Ballroom (September 5, 2013)',
#   'Event Number': 70,
#   'Latitude': '-122.6634854',
#   'Longitude': '45.5408474',
#   'Popularity': '0.163081',
#   'Start Date': '2013-09-05',
#   'Start Time': '22:30:00',
#   'Venue': 'Wonder Ballroom'},
#  {'City': 'Oakdale, CA, US',
#   'Event Name': 'Symbiosis Gathering 2013',
#   'Event Number': 71,
#   'Latitude': '-120.84715',
#   'Longitude': '37.76659',
#   'Popularity': '0.098541',
#   'Start Date': '2013-09-20',
#   'Start Time': '20:00:00',
#   'Venue': 'Woodward Reservoir Regional Park'},
#  {'City': 'Fairburn, GA, US',
#   'Event Name': 'TomorrowWorld 2013',
#   'Event Number': 72,
#   'Latitude': '-84.70753',
#   'Longitude': '33.63613',
#   'Popularity': '0.638161',
#   'Start Date': '2013-09-27',
#   'Start Time': '10:00:00',
#   'Venue': 'Chattahoochee Hills'},
#  {'City': 'San Marcos, TX, US',
#   'Event Name': 'RL Grime at The Marc (October 1, 2013)',
#   'Event Number': 73,
#   'Latitude': '-97.940488',
#   'Longitude': '29.881944',
#   'Popularity': '0.038505',
#   'Start Date': '2013-10-01',
#   'Start Time': '22:00:00',
#   'Venue': 'The Marc'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'RL Grime at Empire Control Room & Garage (October 2, 2013)',
#   'Event Number': 74,
#   'Latitude': '-97.736052',
#   'Longitude': '30.2674374',
#   'Popularity': '0.038505',
#   'Start Date': '2013-10-02',
#   'Start Time': '22:00:00',
#   'Venue': 'Empire Control Room & Garage'},
#  {'City': 'El Paso, TX, US',
#   'Event Name': 'RL Grime with Stereo Thieves at The Plum (October 3, 2013)',
#   'Event Number': 75,
#   'Latitude': '-106.493901',
#   'Longitude': '31.7575783',
#   'Popularity': '0.038505',
#   'Start Date': '2013-10-03',
#   'Start Time': '22:00:00',
#   'Venue': 'The Plum'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'RL Grime at Grand Central (October 29, 2013)',
#   'Event Number': 76,
#   'Latitude': '-80.193623',
#   'Longitude': '25.780664',
#   'Popularity': '0.038505',
#   'Start Date': '2013-10-29',
#   'Start Time': '22:00:00',
#   'Venue': 'Grand Central'},
#  {'City': 'Brooklyn, NY, US',
#   'Event Name': 'RL Grime with DJ Wonder at Music Hall of Williamsburg (October 30, 2013)',
#   'Event Number': 77,
#   'Latitude': '-73.9617103',
#   'Longitude': '40.7192832',
#   'Popularity': '0.038505',
#   'Start Date': '2013-10-30',
#   'Start Time': '21:00:00',
#   'Venue': 'Music Hall of Williamsburg'},
#  {'City': 'San Francisco, CA, US',
#   'Event Name': 'Mad Hatters Ball Ft Rl Grime, RL Grime, Lowriderz, Gladkill, and 10 more… at 1015 Folsom (October 31, 2013)',
#   'Event Number': 78,
#   'Latitude': '-122.405681',
#   'Longitude': '37.778048',
#   'Popularity': '0.038658',
#   'Start Date': '2013-10-31',
#   'Start Time': '22:00:00',
#   'Venue': '1015 Folsom'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'RL Grime with Tory Lanez at Trees (November 1, 2013)',
#   'Event Number': 79,
#   'Latitude': '-96.7844176',
#   'Longitude': '32.7846109',
#   'Popularity': '0.074054',
#   'Start Date': '2013-11-01',
#   'Start Time': '20:00:00',
#   'Venue': 'Trees'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'Hard Day of the Dead 2013',
#   'Event Number': 80,
#   'Latitude': '-118.23427',
#   'Longitude': '34.06617',
#   'Popularity': '0.633921',
#   'Start Date': '2013-11-02',
#   'Start Time': '12:00:00',
#   'Venue': 'Los Angeles State Historic Park'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (November 23, 2013)',
#   'Event Number': 81,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2013-11-23',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'Zeds Dead and RL Grime with Keys N Krates and Orchard Lounge at Aragon Ballroom (December 28, 2013)',
#   'Event Number': 82,
#   'Latitude': '-87.6579453',
#   'Longitude': '41.9692552',
#   'Popularity': '0.062667',
#   'Start Date': '2013-12-28',
#   'Start Time': 'None',
#   'Venue': 'Aragon Ballroom'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'Wolfgang Gartner, Brodinski, Gesaffelstein, and RL Grime at Webster Hall (December 31, 2013)',
#   'Event Number': 83,
#   'Latitude': '-73.9891987',
#   'Longitude': '40.7315472',
#   'Popularity': '0.060229',
#   'Start Date': '2013-12-31',
#   'Start Time': '20:00:00',
#   'Venue': 'Webster Hall'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'Holy Ship 2014',
#   'Event Number': 84,
#   'Latitude': '-80.1779',
#   'Longitude': '25.77876',
#   'Popularity': '0.422826',
#   'Start Date': '2014-01-09',
#   'Start Time': 'None',
#   'Venue': 'Holy Ship'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'RL Grime with Salva at El Rey Theatre (January 23, 2014)',
#   'Event Number': 85,
#   'Latitude': '-118.3487992',
#   'Longitude': '34.062397',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-23',
#   'Start Time': '20:00:00',
#   'Venue': 'El Rey Theatre'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'RL Grime with Salva at El Rey Theatre (January 24, 2014)',
#   'Event Number': 86,
#   'Latitude': '-118.3487992',
#   'Longitude': '34.062397',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-24',
#   'Start Time': '21:00:00',
#   'Venue': 'El Rey Theatre'},
#  {'City': 'Bloomington, IN, US',
#   'Event Name': 'RL Grime and Salva at Bluebird (January 25, 2014)',
#   'Event Number': 87,
#   'Latitude': '-86.5333085',
#   'Longitude': '39.1681261',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-25',
#   'Start Time': '22:00:00',
#   'Venue': 'Bluebird'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'RL Grime with Salva and Lush at U Street Music Hall (January 26, 2014)',
#   'Event Number': 88,
#   'Latitude': '-77.027764',
#   'Longitude': '38.917202',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-26',
#   'Start Time': '21:00:00',
#   'Venue': 'U Street Music Hall'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Surrender, Wynn Las Vegas (January 29, 2014)',
#   'Event Number': 89,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-29',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Denver, CO, US',
#   'Event Name': 'Juicy J with RL Grime, Salva, and Bass Physics at The Fillmore Auditorium (January 30, 2014)',
#   'Event Number': 90,
#   'Latitude': '-104.977259',
#   'Longitude': '39.7403904',
#   'Popularity': '0.167142',
#   'Start Date': '2014-01-30',
#   'Start Time': '19:00:00',
#   'Venue': 'The Fillmore Auditorium'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'RL Grime and Salva at Union Transfer (January 31, 2014)',
#   'Event Number': 91,
#   'Latitude': '-75.155307',
#   'Longitude': '39.9616234',
#   'Popularity': '0.038505',
#   'Start Date': '2014-01-31',
#   'Start Time': '23:59:00',
#   'Venue': 'Union Transfer'},
#  {'City': 'Tallahassee, FL, US',
#   'Event Name': 'RL Grime with Salva, Team Jaguar, and Zav at TENN (February 2, 2014)',
#   'Event Number': 92,
#   'Latitude': '-84.293351',
#   'Longitude': '30.445012',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-02',
#   'Start Time': '22:00:00',
#   'Venue': 'TENN'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Salva and RL Grime at XS Nightclub, the Wynn (February 3, 2014)',
#   'Event Number': 93,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-03',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'RL Grime and Salva with Zebo at The Mid (February 7, 2014)',
#   'Event Number': 94,
#   'Latitude': '-87.6476461',
#   'Longitude': '41.887093',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-07',
#   'Start Time': '22:00:00',
#   'Venue': 'The Mid'},
#  {'City': 'Gainesville, FL, US',
#   'Event Name': 'RL Grime and Salva at Simons (February 13, 2014)',
#   'Event Number': 95,
#   'Latitude': '-82.3255687',
#   'Longitude': '29.651616',
#   'Popularity': '0.03881',
#   'Start Date': '2014-02-13',
#   'Start Time': '22:00:00',
#   'Venue': 'Simons'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'RL Grime and Salva with Mike Deuce and Rowland Evans at Grand Central (February 14, 2014)',
#   'Event Number': 96,
#   'Latitude': '-80.193623',
#   'Longitude': '25.780664',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-14',
#   'Start Time': '22:00:00',
#   'Venue': 'Grand Central'},
#  {'City': 'Orlando, FL, US',
#   'Event Name': 'RL Grime and Salva at Roxy (February 15, 2014)',
#   'Event Number': 97,
#   'Latitude': '-81.334612',
#   'Longitude': '28.554988',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-15',
#   'Start Time': '22:00:00',
#   'Venue': 'Roxy'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (February 16, 2014)',
#   'Event Number': 98,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-02-16',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime and What So Not at XS Nightclub, the Wynn (March 23, 2014)',
#   'Event Number': 99,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.04089',
#   'Start Date': '2014-03-23',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'Boys Noize with Zeds Dead, RL Grime, Cashmere Cat, and 7 more… at Grand Central (March 26, 2014)',
#   'Event Number': 100,
#   'Latitude': '-80.193623',
#   'Longitude': '25.780664',
#   'Popularity': '0.062778',
#   'Start Date': '2014-03-26',
#   'Start Time': '22:00:00',
#   'Venue': 'Grand Central'},
#  {'City': 'Gainesville, FL, US',
#   'Event Name': 'RL Grime and What So Not at Simons (April 2, 2014)',
#   'Event Number': 101,
#   'Latitude': '-82.3255687',
#   'Longitude': '29.651616',
#   'Popularity': '0.04089',
#   'Start Date': '2014-04-02',
#   'Start Time': '22:00:00',
#   'Venue': 'Simons'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella 2014',
#   'Event Number': 102,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.638306',
#   'Start Date': '2014-04-11',
#   'Start Time': '23:59:20',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Surrender, Wynn Las Vegas (April 11, 2014)',
#   'Event Number': 103,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-04-11',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Indio, CA, US',
#   'Event Name': 'Coachella 2014',
#   'Event Number': 104,
#   'Latitude': '-116.23892',
#   'Longitude': '33.68233',
#   'Popularity': '0.638306',
#   'Start Date': '2014-04-18',
#   'Start Time': '12:00:00',
#   'Venue': 'Empire Polo Club'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (April 28, 2014)',
#   'Event Number': 105,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-04-28',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'JMBLYA with Chance the Rapper, RL Grime, A$AP Ferg, and 9 more… at Trees (May 2, 2014)',
#   'Event Number': 106,
#   'Latitude': '-96.78442',
#   'Longitude': '32.78461',
#   'Popularity': '0.232249',
#   'Start Date': '2014-05-02',
#   'Start Time': '20:00:00',
#   'Venue': 'Trees'},
#  {'City': 'New Braunfels, TX, US',
#   'Event Name': 'JMBLYA, Baauer, and RL Grime with Cashmere Cat and 9 more… at WhiteWater Amphitheater (May 3, 2014)',
#   'Event Number': 107,
#   'Latitude': '-98.15766',
#   'Longitude': '29.8611',
#   'Popularity': '0.232249',
#   'Start Date': '2014-05-03',
#   'Start Time': '16:00:00',
#   'Venue': 'WhiteWater Amphitheater'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'RL Grime with Dubbel Dutch at Webster Hall (May 6, 2014)',
#   'Event Number': 108,
#   'Latitude': '-73.9891987',
#   'Longitude': '40.7315472',
#   'Popularity': '0.038505',
#   'Start Date': '2014-05-06',
#   'Start Time': '20:00:00',
#   'Venue': 'Webster Hall'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Surrender, Wynn Las Vegas (May 7, 2014)',
#   'Event Number': 109,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-05-07',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Lil Jon and RL Grime at Encore Beach Club, Wynn Las Vegas (May 18, 2014)',
#   'Event Number': 110,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.121991',
#   'Start Date': '2014-05-18',
#   'Start Time': '11:00:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime and Paper Diamond at Surrender, Wynn Las Vegas (May 28, 2014)',
#   'Event Number': 111,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-05-28',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (June 2, 2014)',
#   'Event Number': 112,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-06-02',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'The Dalles, OR, US',
#   'Event Name': 'What the Festival 2014',
#   'Event Number': 113,
#   'Latitude': '-121.08971',
#   'Longitude': '45.54345',
#   'Popularity': '0.199849',
#   'Start Date': '2014-06-19',
#   'Start Time': 'None',
#   'Venue': 'Wolf Run Ranch'},
#  {'City': 'Morrison, CO, US',
#   'Event Name': 'Skrillex with DJ Snake, Pusha T, RL Grime, and 1 more… at Red Rocks Amphitheatre (June 20, 2014)',
#   'Event Number': 114,
#   'Latitude': '-105.1972399',
#   'Longitude': '39.6800052',
#   'Popularity': '0.42199',
#   'Start Date': '2014-06-20',
#   'Start Time': '19:30:00',
#   'Venue': 'Red Rocks Amphitheatre'},
#  {'City': 'Portland, OR, US',
#   'Event Name': 'What the Festival 2014',
#   'Event Number': 115,
#   'Latitude': '-122.67648',
#   'Longitude': '45.52306',
#   'Popularity': '0.108841',
#   'Start Date': '2014-06-22',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Diplo, Skrillex, and RL Grime at XS Nightclub, the Wynn (June 23, 2014)',
#   'Event Number': 116,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.4176',
#   'Start Date': '2014-06-23',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Surrender, Wynn Las Vegas (June 27, 2014)',
#   'Event Number': 117,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-06-27',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Surrender, Wynn Las Vegas (July 23, 2014)',
#   'Event Number': 118,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-07-23',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Santa Ana, CA, US',
#   'Event Name': 'RL Grime at The Observatory (July 24, 2014)',
#   'Event Number': 119,
#   'Latitude': '-117.9194457',
#   'Longitude': '33.6998449',
#   'Popularity': '0.038505',
#   'Start Date': '2014-07-24',
#   'Start Time': '20:00:00',
#   'Venue': 'The Observatory'},
#  {'City': 'Pomona, CA, US',
#   'Event Name': 'RL Grime with Groundislava and Nick Melons at The Glass House (July 26, 2014)',
#   'Event Number': 120,
#   'Latitude': '-117.751453',
#   'Longitude': '34.057535',
#   'Popularity': '0.038505',
#   'Start Date': '2014-07-26',
#   'Start Time': '19:00:00',
#   'Venue': 'The Glass House'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (August 10, 2014)',
#   'Event Number': 121,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-08-10',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Somerset, WI, US',
#   'Event Name': 'Summerset Music Festival 2014',
#   'Event Number': 122,
#   'Latitude': '-92.68526',
#   'Longitude': '45.13023',
#   'Popularity': '0.276628',
#   'Start Date': '2014-08-15',
#   'Start Time': 'None',
#   'Venue': 'Somerset Amphitheater'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Diplo and RL Grime at XS Nightclub, the Wynn (August 18, 2014)',
#   'Event Number': 123,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.163081',
#   'Start Date': '2014-08-18',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'New Orleans, LA, US',
#   'Event Name': 'A$AP Ferg, Big Gigantic, Dillon Francis, Kid Kamillion, and 4 more… at Mardi Gras World (August 29, 2014)',
#   'Event Number': 124,
#   'Latitude': '-90.0615085',
#   'Longitude': '29.9349266',
#   'Popularity': '0.124925',
#   'Start Date': '2014-08-29',
#   'Start Time': '14:00:00',
#   'Venue': 'Mardi Gras World'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime and Pegboard Nerds at Surrender, Wynn Las Vegas (September 3, 2014)',
#   'Event Number': 125,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-09-03',
#   'Start Time': '22:30:00',
#   'Venue': 'Surrender, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (October 13, 2014)',
#   'Event Number': 126,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-10-13',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Philadelphia, PA, US',
#   'Event Name': 'RL Grime at Electric Factory (October 30, 2014)',
#   'Event Number': 127,
#   'Latitude': '-75.1502809',
#   'Longitude': '39.9589847',
#   'Popularity': '0.038505',
#   'Start Date': '2014-10-30',
#   'Start Time': '20:30:00',
#   'Venue': 'Electric Factory'},
#  {'City': 'Washington, DC, US',
#   'Event Name': 'RL Grime with Branchez and Tommy Kruise at 9:30 Club (October 31, 2014)',
#   'Event Number': 128,
#   'Latitude': '-77.0237219',
#   'Longitude': '38.9178658',
#   'Popularity': '0.038658',
#   'Start Date': '2014-10-31',
#   'Start Time': '22:00:00',
#   'Venue': '9:30 Club'},
#  {'City': 'Richmond, VA, US',
#   'Event Name': 'RL Grime, Branchez, and Tommy Kruise at The National (November 1, 2014)',
#   'Event Number': 129,
#   'Latitude': '-77.4353949',
#   'Longitude': '37.5417961',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-01',
#   'Start Time': '20:00:00',
#   'Venue': 'The National'},
#  {'City': 'Pomona, CA, US',
#   'Event Name': 'Hard Day of the Dead 2014',
#   'Event Number': 130,
#   'Latitude': '-117.76581',
#   'Longitude': '34.08015',
#   'Popularity': '0.638161',
#   'Start Date': '2014-11-01',
#   'Start Time': '11:00:00',
#   'Venue': 'Fairplex'},
#  {'City': 'South Burlington, VT, US',
#   'Event Name': 'RL Grime with Branchez and Tommy Kruise at Higher Ground (November 5, 2014)',
#   'Event Number': 131,
#   'Latitude': '-73.17564',
#   'Longitude': '44.468887',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-05',
#   'Start Time': '20:30:00',
#   'Venue': 'Higher Ground'},
#  {'City': 'Boston, MA, US',
#   'Event Name': 'RL Grime, Branchez, and Tommy Kruise at Paradise Rock Club (November 6, 2014)',
#   'Event Number': 132,
#   'Latitude': '-71.1096202',
#   'Longitude': '42.3504745',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-06',
#   'Start Time': '20:00:00',
#   'Venue': 'Paradise Rock Club'},
#  {'City': 'Syracuse, NY, US',
#   'Event Name': 'RL Grime at Westcott Theater (November 7, 2014)',
#   'Event Number': 133,
#   'Latitude': '-76.1195833',
#   'Longitude': '43.0412032',
#   'Popularity': '0.038559',
#   'Start Date': '2014-11-07',
#   'Start Time': '20:00:00',
#   'Venue': 'Westcott Theater'},
#  {'City': 'Buffalo, NY, US',
#   'Event Name': 'RL Grime with Branchez and Tommy Kruise at Waiting Room (November 8, 2014)',
#   'Event Number': 134,
#   'Latitude': '-78.876413',
#   'Longitude': '42.893541',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-08',
#   'Start Time': '20:00:00',
#   'Venue': 'Waiting Room'},
#  {'City': 'Millvale, PA, US',
#   'Event Name': "RL Grime with Branchez and Tommy Kruise at Mr. Small's Theatre (November 9, 2014)",
#   'Event Number': 135,
#   'Latitude': '-79.97268',
#   'Longitude': '40.481268',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-09',
#   'Start Time': '20:00:00',
#   'Venue': "Mr. Small's Theatre"},
#  {'City': 'Cleveland, OH, US',
#   'Event Name': 'RL Grime, Branchez, and Tommy Kruise at House of Blues (November 10, 2014)',
#   'Event Number': 136,
#   'Latitude': '-81.6908598',
#   'Longitude': '41.4998193',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-10',
#   'Start Time': '21:00:00',
#   'Venue': 'House of Blues'},
#  {'City': 'Columbus, OH, US',
#   'Event Name': 'RL Grime at Bluestone (November 12, 2014)',
#   'Event Number': 137,
#   'Latitude': '-82.984967',
#   'Longitude': '39.96359',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-12',
#   'Start Time': '21:00:00',
#   'Venue': 'Bluestone'},
#  {'City': 'Royal Oak, MI, US',
#   'Event Name': 'RL Grime with Branchez and Tommy Kruise at Royal Oak Music Theatre (November 13, 2014)',
#   'Event Number': 138,
#   'Latitude': '-83.1474339',
#   'Longitude': '42.4873251',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-13',
#   'Start Time': '20:00:00',
#   'Venue': 'Royal Oak Music Theatre'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'RL Grime at Concord Music Hall (November 14, 2014)',
#   'Event Number': 139,
#   'Latitude': '-87.6900284',
#   'Longitude': '41.9185623',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-14',
#   'Start Time': '20:00:00',
#   'Venue': 'Concord Music Hall'},
#  {'City': 'Chicago, IL, US',
#   'Event Name': 'RL Grime at The Mid (November 14, 2014)',
#   'Event Number': 140,
#   'Latitude': '-87.6476461',
#   'Longitude': '41.887093',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-14',
#   'Start Time': '22:00:00',
#   'Venue': 'The Mid'},
#  {'City': 'St Louis, MO, US',
#   'Event Name': 'RL Grime at Old Rock House (November 15, 2014)',
#   'Event Number': 141,
#   'Latitude': '-90.196469',
#   'Longitude': '38.615345',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-15',
#   'Start Time': '21:30:00',
#   'Venue': 'Old Rock House'},
#  {'City': 'Urbana, IL, US',
#   'Event Name': 'RL Grime with Branchez and Tommy Kruise at Canopy Club (November 16, 2014)',
#   'Event Number': 142,
#   'Latitude': '-88.2233873',
#   'Longitude': '40.1066524',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-16',
#   'Start Time': '21:00:00',
#   'Venue': 'Canopy Club'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (November 17, 2014)',
#   'Event Number': 143,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-17',
#   'Start Time': '22:00:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Milwaukee, WI, US',
#   'Event Name': 'RL Grime at Turner Hall Ballroom (November 18, 2014)',
#   'Event Number': 144,
#   'Latitude': '-87.9158037',
#   'Longitude': '43.0440262',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-18',
#   'Start Time': '19:30:00',
#   'Venue': 'Turner Hall Ballroom'},
#  {'City': 'Madison, WI, US',
#   'Event Name': 'RL Grime at Majestic Theatre (November 19, 2014)',
#   'Event Number': 145,
#   'Latitude': '-89.3807714',
#   'Longitude': '43.074528',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-19',
#   'Start Time': '21:00:00',
#   'Venue': 'Majestic Theatre'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'RL Grime at Mill City Nights (November 20, 2014)',
#   'Event Number': 146,
#   'Latitude': '-93.2739195',
#   'Longitude': '44.9804999',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-20',
#   'Start Time': '21:00:00',
#   'Venue': 'Mill City Nights'},
#  {'City': 'Lawrence, KS, US',
#   'Event Name': 'RL Grime at Granada Theatre (November 21, 2014)',
#   'Event Number': 147,
#   'Latitude': '-95.2358532',
#   'Longitude': '38.9647957',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-21',
#   'Start Time': '21:00:00',
#   'Venue': 'Granada Theatre'},
#  {'City': 'Lincoln, NE, US',
#   'Event Name': 'RL Grime at Bourbon Theatre (November 22, 2014)',
#   'Event Number': 148,
#   'Latitude': '-96.700617',
#   'Longitude': '40.813249',
#   'Popularity': '0.038505',
#   'Start Date': '2014-11-22',
#   'Start Time': '21:00:00',
#   'Venue': 'Bourbon Theatre'},
#  {'City': 'Denver, CO, US',
#   'Event Name': 'RL Grime with Lunice and Branchez at Ogden Theatre (November 23, 2014)',
#   'Event Number': 149,
#   'Latitude': '-104.975305',
#   'Longitude': '39.740118',
#   'Popularity': '0.038658',
#   'Start Date': '2014-11-23',
#   'Start Time': '20:30:00',
#   'Venue': 'Ogden Theatre'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'RL Grime with Lunice and Branchez at The Ballroom at Warehouse Live (December 10, 2014)',
#   'Event Number': 150,
#   'Latitude': '-95.3546736',
#   'Longitude': '29.7521221',
#   'Popularity': '0.038658',
#   'Start Date': '2014-12-10',
#   'Start Time': '20:00:00',
#   'Venue': 'The Ballroom at Warehouse Live'},
#  {'City': 'Austin, TX, US',
#   'Event Name': "RL Grime with Branchez and Lunice at Emo's Austin (December 11, 2014)",
#   'Event Number': 151,
#   'Latitude': '-97.7282016',
#   'Longitude': '30.2403964',
#   'Popularity': '0.038658',
#   'Start Date': '2014-12-11',
#   'Start Time': '20:30:00',
#   'Venue': "Emo's Austin"},
#  {'City': 'Dallas, TX, US',
#   'Event Name': 'RL Grime with Black Veil Brides, Lunice, and Branchez at South Side Music Hall (December 12, 2014)',
#   'Event Number': 152,
#   'Latitude': '-96.797987',
#   'Longitude': '32.768777',
#   'Popularity': '0.066469',
#   'Start Date': '2014-12-12',
#   'Start Time': '20:30:00',
#   'Venue': 'South Side Music Hall'},
#  {'City': 'Baton Rouge, LA, US',
#   'Event Name': 'RL Grime with Lunice and Branchez at Varsity Theatre (December 13, 2014)',
#   'Event Number': 153,
#   'Latitude': '-91.1762795',
#   'Longitude': '30.4173942',
#   'Popularity': '0.038658',
#   'Start Date': '2014-12-13',
#   'Start Time': '21:00:00',
#   'Venue': 'Varsity Theatre'},
#  {'City': 'New Orleans, LA, US',
#   'Event Name': 'RL Grime at Republic (December 14, 2014)',
#   'Event Number': 154,
#   'Latitude': '-90.0657445',
#   'Longitude': '29.9440872',
#   'Popularity': '0.038505',
#   'Start Date': '2014-12-14',
#   'Start Time': '19:00:00',
#   'Venue': 'Republic'},
#  {'City': 'Atlanta, GA, US',
#   'Event Name': 'RL Grime with Lunice and Branchez at Terminal West (December 15, 2014)',
#   'Event Number': 155,
#   'Latitude': '-84.4172261',
#   'Longitude': '33.7831074',
#   'Popularity': '0.038658',
#   'Start Date': '2014-12-15',
#   'Start Time': '20:00:00',
#   'Venue': 'Terminal West'},
#  {'City': 'Nashville, TN, US',
# ...
#   'Event Number': 393,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038505',
#   'Start Date': '2017-12-08',
#   'Start Time': '22:30:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (December 14, 2017)',
#   'Event Number': 394,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038505',
#   'Start Date': '2017-12-14',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (December 29, 2017)',
#   'Event Number': 395,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038505',
#   'Start Date': '2017-12-29',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Pompano Beach, FL, US',
#   'Event Name': 'RL Grime at Club Cinema (December 30, 2017)',
#   'Event Number': 396,
#   'Latitude': '-80.0981004',
#   'Longitude': '26.2714136',
#   'Popularity': '0.038505',
#   'Start Date': '2017-12-30',
#   'Start Time': '20:00:00',
#   'Venue': 'Club Cinema'},
#  {'City': 'Houston, TX, US',
#   'Event Name': 'RL Grime with Spire at Spire Night Club (December 31, 2017)',
#   'Event Number': 397,
#   'Latitude': '-95.3698616',
#   'Longitude': '29.7513482',
#   'Popularity': '0.039189',
#   'Start Date': '2017-12-31',
#   'Start Time': '22:00:00',
#   'Venue': 'Spire Night Club'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (January 31, 2018)',
#   'Event Number': 398,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038505',
#   'Start Date': '2018-01-31',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Minneapolis, MN, US',
#   'Event Name': 'The Barstool Party 2018',
#   'Event Number': 399,
#   'Latitude': '-93.3007481',
#   'Longitude': '45.1908533',
#   'Popularity': '0.126638',
#   'Start Date': '2018-02-02',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (February 3, 2018)',
#   'Event Number': 400,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038513',
#   'Start Date': '2018-02-03',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (February 9, 2018)',
#   'Event Number': 401,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038537',
#   'Start Date': '2018-02-09',
#   'Start Time': '22:30:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (February 16, 2018)',
#   'Event Number': 402,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038572',
#   'Start Date': '2018-02-16',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (February 23, 2018)',
#   'Event Number': 403,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038582',
#   'Start Date': '2018-02-23',
#   'Start Time': '22:30:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Atlantic City, NJ, US',
#   'Event Name': 'RL Grime at Premier Nightclub Ac (February 24, 2018)',
#   'Event Number': 404,
#   'Latitude': '-74.4352455',
#   'Longitude': '39.3783325',
#   'Popularity': '0.03858',
#   'Start Date': '2018-02-24',
#   'Start Time': 'None',
#   'Venue': 'Premier Nightclub Ac'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (February 28, 2018)',
#   'Event Number': 405,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038592',
#   'Start Date': '2018-02-28',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (March 4, 2018)',
#   'Event Number': 406,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038607',
#   'Start Date': '2018-03-04',
#   'Start Time': '22:30:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Park City, UT, US',
#   'Event Name': 'RL Grime at Park City Live (March 9, 2018)',
#   'Event Number': 407,
#   'Latitude': '-111.4960837',
#   'Longitude': '40.6437778',
#   'Popularity': '0.038622',
#   'Start Date': '2018-03-09',
#   'Start Time': 'None',
#   'Venue': 'Park City Live'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (March 10, 2018)',
#   'Event Number': 408,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038625',
#   'Start Date': '2018-03-10',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (March 17, 2018)',
#   'Event Number': 409,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038647',
#   'Start Date': '2018-03-17',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'Ultra Music Festival 2018',
#   'Event Number': 410,
#   'Latitude': '-80.18745',
#   'Longitude': '25.77707',
#   'Popularity': '0.600524',
#   'Start Date': '2018-03-23',
#   'Start Time': 'None',
#   'Venue': 'Bayfront Park'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (March 23, 2018)',
#   'Event Number': 411,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038666',
#   'Start Date': '2018-03-23',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Austin, TX, US',
#   'Event Name': 'RL Grime at Vulcan Gas Company (March 24, 2018)',
#   'Event Number': 412,
#   'Latitude': '-97.738465',
#   'Longitude': '30.267162',
#   'Popularity': '0.038671',
#   'Start Date': '2018-03-24',
#   'Start Time': 'None',
#   'Venue': 'Vulcan Gas Company'},
#  {'City': 'Miami, FL, US',
#   'Event Name': 'RL Grime at Gold Rush Cabaret (March 25, 2018)',
#   'Event Number': 413,
#   'Latitude': '-80.1848475',
#   'Longitude': '25.8469388',
#   'Popularity': '0.038675',
#   'Start Date': '2018-03-25',
#   'Start Time': '10:00:00',
#   'Venue': 'Gold Rush Cabaret'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (March 29, 2018)',
#   'Event Number': 414,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038705',
#   'Start Date': '2018-03-29',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (March 31, 2018)',
#   'Event Number': 415,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038713',
#   'Start Date': '2018-03-31',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (April 7, 2018)',
#   'Event Number': 416,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038746',
#   'Start Date': '2018-04-07',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (April 19, 2018)',
#   'Event Number': 417,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038822',
#   'Start Date': '2018-04-19',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Athens, OH, US',
#   'Event Name': 'Number Fest: 16th Edition 2018',
#   'Event Number': 418,
#   'Latitude': 'None',
#   'Longitude': 'None',
#   'Popularity': '0.038836',
#   'Start Date': '2018-04-20',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (April 21, 2018)',
#   'Event Number': 419,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038836',
#   'Start Date': '2018-04-21',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (April 28, 2018)',
#   'Event Number': 420,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038862',
#   'Start Date': '2018-04-28',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (May 4, 2018)',
#   'Event Number': 421,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038885',
#   'Start Date': '2018-05-04',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Lost Kings and RL Grime at Intrigue Nightclub (May 9, 2018)',
#   'Event Number': 422,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.038911',
#   'Start Date': '2018-05-09',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at XS Nightclub, the Wynn (May 13, 2018)',
#   'Event Number': 423,
#   'Latitude': '-115.1649668',
#   'Longitude': '36.1294702',
#   'Popularity': '0.038948',
#   'Start Date': '2018-05-13',
#   'Start Time': '22:30:00',
#   'Venue': 'XS Nightclub, the Wynn'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Encore Beach Club and RL Grime at Encore Beach Club, Wynn Las Vegas (May 19, 2018)',
#   'Event Number': 424,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.038998',
#   'Start Date': '2018-05-19',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Chillicothe, IL, US',
#   'Event Name': 'Summer Camp Music Festival 2018',
#   'Event Number': 425,
#   'Latitude': '-89.48609',
#   'Longitude': '40.93165',
#   'Popularity': '0.178459',
#   'Start Date': '2018-05-25',
#   'Start Time': 'None',
#   'Venue': 'Three Sisters Park'},
#  {'City': 'San Diego, CA, US',
#   'Event Name': 'My Life Every Day Usa and Galantis with RIOT TEN, Jackal, and 9 more… at Valley View Casino Center (May 25, 2018)',
#   'Event Number': 426,
#   'Latitude': '-117.2117942',
#   'Longitude': '32.7550767',
#   'Popularity': '0.106727',
#   'Start Date': '2018-05-25',
#   'Start Time': '21:00:00',
#   'Venue': 'Valley View Casino Center'},
#  {'City': 'San Diego, CA, US',
#   'Event Name': 'My Life Every Day USA 2018',
#   'Event Number': 427,
#   'Latitude': '-117.1594048',
#   'Longitude': '32.7150885',
#   'Popularity': '0.039065',
#   'Start Date': '2018-05-25',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'San Diego, CA, US',
#   'Event Name': 'RL Grime at Hard Rock Hotel - San Diego (May 26, 2018)',
#   'Event Number': 428,
#   'Latitude': '-117.1597559',
#   'Longitude': '32.707464',
#   'Popularity': '0.039065',
#   'Start Date': '2018-05-26',
#   'Start Time': '14:00:00',
#   'Venue': 'Hard Rock Hotel - San Diego'},
#  {'City': 'Scottsdale, AZ, US',
#   'Event Name': 'RL Grime at Release Pool Party (May 27, 2018)',
#   'Event Number': 429,
#   'Latitude': '-111.869849',
#   'Longitude': '33.540113',
#   'Popularity': '0.039072',
#   'Start Date': '2018-05-27',
#   'Start Time': '12:00:00',
#   'Venue': 'Release Pool Party'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (June 2, 2018)',
#   'Event Number': 430,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.039134',
#   'Start Date': '2018-06-02',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime and Flosstradamus at Encore Beach Club, Wynn Las Vegas (June 14, 2018)',
#   'Event Number': 431,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.052055',
#   'Start Date': '2018-06-14',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (June 29, 2018)',
#   'Event Number': 432,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.039434',
#   'Start Date': '2018-06-29',
#   'Start Time': '10:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (July 6, 2018)',
#   'Event Number': 433,
#   'Latitude': '-115.165129',
#   'Longitude': '36.130189',
#   'Popularity': '0.039489',
#   'Start Date': '2018-07-06',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (July 13, 2018)',
#   'Event Number': 434,
#   'Latitude': '-115.1653038',
#   'Longitude': '36.1293962',
#   'Popularity': '0.039564',
#   'Start Date': '2018-07-13',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'New York, NY, US',
#   'Event Name': 'The Greatest Day Ever 2018',
#   'Event Number': 435,
#   'Latitude': '-74.0059413',
#   'Longitude': '40.7127837',
#   'Popularity': '0.044048',
#   'Start Date': '2018-07-14',
#   'Start Time': 'None',
#   'Venue': 'Unknown venue'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'Intrigue and RL Grime at Intrigue Nightclub (July 25, 2018)',
#   'Event Number': 436,
#   'Latitude': '-115.1653',
#   'Longitude': '36.1294',
#   'Popularity': '0.039696',
#   'Start Date': '2018-07-25',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (July 27, 2018)',
#   'Event Number': 437,
#   'Latitude': '-115.1653',
#   'Longitude': '36.1294',
#   'Popularity': '0.039735',
#   'Start Date': '2018-07-27',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (August 2, 2018)',
#   'Event Number': 438,
#   'Latitude': '-115.16513',
#   'Longitude': '36.13019',
#   'Popularity': '0.039837',
#   'Start Date': '2018-08-02',
#   'Start Time': '22:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Miami Beach, FL, US',
#   'Event Name': 'RL Grime at Story Nightclub (August 3, 2018)',
#   'Event Number': 439,
#   'Latitude': '-80.13421',
#   'Longitude': '25.7705',
#   'Popularity': '0.039853',
#   'Start Date': '2018-08-03',
#   'Start Time': '11:00:00',
#   'Venue': 'Story Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (August 10, 2018)',
#   'Event Number': 440,
#   'Latitude': '-115.16513',
#   'Longitude': '36.13019',
#   'Popularity': '0.040002',
#   'Start Date': '2018-08-10',
#   'Start Time': '10:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (August 11, 2018)',
#   'Event Number': 441,
#   'Latitude': '-115.1653',
#   'Longitude': '36.1294',
#   'Popularity': '0.040017',
#   'Start Date': '2018-08-11',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Des Moines, IA, US',
#   'Event Name': '515 Alive 2018',
#   'Event Number': 442,
#   'Latitude': '-93.6474',
#   'Longitude': '41.56896',
#   'Popularity': '0.328116',
#   'Start Date': '2018-08-17',
#   'Start Time': 'None',
#   'Venue': 'Water Works Park'},
#  {'City': 'Los Angeles, CA, US',
#   'Event Name': 'All My Friends Festival 2018',
#   'Event Number': 443,
#   'Latitude': '-118.24149',
#   'Longitude': '34.03369',
#   'Popularity': '0.239875',
#   'Start Date': '2018-08-18',
#   'Start Time': '00:00:00',
#   'Venue': 'The Row DTLA'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Intrigue Nightclub (August 25, 2018)',
#   'Event Number': 444,
#   'Latitude': '-115.1653',
#   'Longitude': '36.1294',
#   'Popularity': '0.040283',
#   'Start Date': '2018-08-25',
#   'Start Time': '22:30:00',
#   'Venue': 'Intrigue Nightclub'},
#  {'City': 'Las Vegas, NV, US',
#   'Event Name': 'RL Grime at Encore Beach Club, Wynn Las Vegas (August 26, 2018)',
#   'Event Number': 445,
#   'Latitude': '-115.16513',
#   'Longitude': '36.13019',
#   'Popularity': '0.040293',
#   'Start Date': '2018-08-26',
#   'Start Time': '10:30:00',
#   'Venue': 'Encore Beach Club, Wynn Las Vegas'}]
